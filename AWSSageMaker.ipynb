# %% [markdown]
# Version: 02.14.2023

# %% [markdown]
# # Lab 6.2: Implementing Topic Extraction with NTM
#
# In this lab, you will use the Amazon SageMaker Neural Topic Model (NTM) algorithm to extract topics from the [20 Newsgroups](https://archive.ics.uci.edu/ml/datasets/Twenty+Newsgroups) dataset.
#
# The Amazon SageMaker Neural Topic Model (NTM) is an unsupervised learning algorithm that attempts to describe a set of observations as a mixture of distinct categories. NTM is most commonly used to discover a user-specified number of topics that are shared by documents within a text corpus.
#
# Each observation is a document, the features are the presence (or occurrence count) of each word, and the categories are the topics. Because the method is unsupervised, the topics are not specified up front and are not guaranteed to align with how a human might naturally categorize documents. The topics are learned as a probability distribution over the words that occur in each document. Each document, in turn, is described as a mixture of topics. For more information, see [Neural Topic Model (NTM) Algorithm](https://docs.aws.amazon.com/sagemaker/latest/dg/ntm.html) in the Amazon SageMaker Developer Guide.
#
#
# ## About this dataset
#
# The 20 Newsgroups dataset is a collection of approximately 20,000 newsgroup documents, partitioned (nearly) evenly across 20 different newsgroups. This collection has become a popular dataset for experiments in text applications of machine learning techniques, such as text classification and text clustering. In this lab, you will see what topics you can learn from this set of documents using the Neural Topic Model (NTM) algorithm.
#
# Dataset source: Tom Mitchell. *20 Newsgroups Data*. September 9, 1999. Distributed by UCI KDD Archive. https://kdd.ics.uci.edu/databases/20newsgroups/20newsgroups.data.html.

# %% [markdown]
# ## Lab steps
#
# 1. [Fetching the dataset](#1.-Fetching-the-dataset)
# 2. [Examining and preprocessing the data](#2.-Examining-and-preprocessing-the-data)
# 3. [Preparing the data for training](#3.-Preparing-the-data-for-training)
# 4. [Training the model](#4.-Training-the-model)
# 5. [Using the model for inference](#5.-Using-the-model-for-inference)
# 6. [Exploring the model](#6.-Exploring-the-model)
#
# ## Submitting your work
#
# 1. In the lab console, choose **Submit** to record your progress and when prompted, choose **Yes**.
#
# 1. If the results don't display after a couple of minutes, return to the top of the lab instructions and choose **Grades**.
#
#     **Tip:** You can submit your work multiple times. After you change your work, choose **Submit** again. Your last submission is what will be recorded for this lab.
#
# 1. To find detailed feedback on your work, choose **Details** followed by **View Submission Report**.

# %% [markdown]
# ## 1. Fetching the dataset
# ([Go to top](#Lab-6.2:-Implementing-Topic-Extraction-with-NTM))
#
# First, define the folder to hold the data. Then, clean up the folder, which might contain data from previous experiments.

# %%
# !pip install --upgrade pip
# !pip install --upgrade SageMaker
# !pip install --upgrade nltk
print("cell execution completed")
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (22.3.1)
# Collecting pip
#   Downloading pip-23.0.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 58.6 MB/s eta 0:00:0000:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# Successfully installed pip-23.0.1
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: SageMaker in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (2.133.0)
# Collecting SageMaker
#   Downloading sagemaker-2.143.0.tar.gz (706 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.5/706.5 kB 15.1 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: attrs<23,>=20.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (22.2.0)
# Requirement already satisfied: boto3<2.0,>=1.26.28 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (1.26.74)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (1.22.3)
# Requirement already satisfied: protobuf<4.0,>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (3.20.3)
# Requirement already satisfied: protobuf3-to-dict<1.0,>=0.1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (0.1.5)
# Requirement already satisfied: smdebug_rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (1.0.1)
# Requirement already satisfied: importlib-metadata<5.0,>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (4.13.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (21.3)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (1.5.2)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (0.3.0)
# Requirement already satisfied: schema in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (0.7.5)
# Requirement already satisfied: PyYAML==5.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (5.4.1)
# Requirement already satisfied: jsonschema in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (3.2.0)
# Requirement already satisfied: platformdirs in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from SageMaker) (2.6.2)
# Requirement already satisfied: botocore<1.30.0,>=1.29.74 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0,>=1.26.28->SageMaker) (1.29.74)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0,>=1.26.28->SageMaker) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0,>=1.26.28->SageMaker) (0.6.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from importlib-metadata<5.0,>=1.4.0->SageMaker) (3.11.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging>=20.0->SageMaker) (3.0.9)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from protobuf3-to-dict<1.0,>=0.1.5->SageMaker) (1.16.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->SageMaker) (65.6.3)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->SageMaker) (0.19.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas->SageMaker) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas->SageMaker) (2022.7)
# Requirement already satisfied: ppft>=1.7.6.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->SageMaker) (1.7.6.6)
# Requirement already satisfied: pox>=0.3.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->SageMaker) (0.3.2)
# Requirement already satisfied: dill>=0.3.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->SageMaker) (0.3.6)
# Requirement already satisfied: multiprocess>=0.70.14 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->SageMaker) (0.70.14)
# Requirement already satisfied: contextlib2>=0.5.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from schema->SageMaker) (21.6.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.30.0,>=1.29.74->boto3<2.0,>=1.26.28->SageMaker) (1.26.8)
# Building wheels for collected packages: SageMaker
#   Building wheel for SageMaker (setup.py) ... done
#   Created wheel for SageMaker: filename=sagemaker-2.143.0-py2.py3-none-any.whl size=948773 sha256=7b0a2663b03a42b790c4129bafe74b1ff081d230e68066508a4c69f18c44aac6
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/a7/37/d4/72ae4c29f6c8e1ae52507fa9400e1378efe1ad5d14201abc0d
# Successfully built SageMaker
# Installing collected packages: SageMaker
#   Attempting uninstall: SageMaker
#     Found existing installation: sagemaker 2.133.0
#     Uninstalling sagemaker-2.133.0:
#       Successfully uninstalled sagemaker-2.133.0
# Successfully installed SageMaker-2.143.0
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: nltk in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: joblib in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from nltk) (4.64.1)
# cell execution completed

# %%
import boto3
import os
import shutil

def check_create_dir(dir):
    if os.path.exists(dir):  # Clean up existing data folder
        shutil.rmtree(dir)
    os.mkdir(dir)

data_dir = '20_newsgroups'
check_create_dir(data_dir)
print("cell execution completed")
# Out:
# cell execution completed

# %% [markdown]
# In the next two cells, you unpack the dataset and extract a list of the files.

# %%
# !tar -xzf ../s3/20_newsgroups.tar.gz
# !ls 20_newsgroups
# Out:
# alt.atheism		  rec.autos	      sci.space
# comp.graphics		  rec.motorcycles     soc.religion.christian
# comp.os.ms-windows.misc   rec.sport.baseball  talk.politics.guns
# comp.sys.ibm.pc.hardware  rec.sport.hockey    talk.politics.mideast
# comp.sys.mac.hardware	  sci.crypt	      talk.politics.misc
# comp.windows.x		  sci.electronics     talk.religion.misc
# misc.forsale		  sci.med

# %%
folders = [os.path.join(data_dir,f) for f in sorted(os.listdir(data_dir)) if os.path.isdir(os.path.join(data_dir, f))]
file_list = [os.path.join(d,f) for d in folders for f in os.listdir(d)]
print('Number of documents:', len(file_list))
# Out:
# Number of documents: 19997

# %% [markdown]
# ## 2. Examining and preprocessing the data
# ([Go to top](#Lab-6.2:-Implementing-Topic-Extraction-with-NTM))
#
# In this section, you will examine the data and perform some standard natural language processing (NLP) data cleaning tasks.

# %% [markdown]
# Remind yourself what the files look like in order to determine the best preprocessing steps to take.

# %%
# !cat 20_newsgroups/comp.graphics/37917
# Out:
# Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv.cs.cmu.edu!fs7.ece.cmu.edu!europa.eng.gtefsd.com!howland.reston.ans.net!usc!elroy.jpl.nasa.gov!nntp-server.caltech.edu!andrey
# From: andrey@cco.caltech.edu (Andre T. Yew)
# Newsgroups: comp.graphics
# Subject: Re: 16 million vs 65 thousand colors
# Date: 3 Apr 1993 19:51:06 GMT
# Organization: California Institute of Technology, Pasadena
# Lines: 28
# Message-ID: <1pkpraINNck9@gap.caltech.edu>
# References: <1993Mar26.210323.27802@midway.uchicago.edu> <dotzlaw-020493084300@murphy.biochem.umanitoba.ca> <d9hh.733845825@dtek.chalmers.se>
# NNTP-Posting-Host: punisher.caltech.edu
#
# d9hh@dtek.chalmers.se (Henrik Harmsen) writes:
#
# >1-4 bits per R/G/B gives horrible machbanding visible in almost any picture.
#
# >5 bits per R/G/B (32768, 65000 colors) gives visible machbanding
#
# >color-gradient picture has _almost_ no machbanding. This color-resolution is
#
# >see some small machbanding on the smooth color-gradient picture, but all in all,
# >There _ARE_ situiations where you get visible mach-banding even in
# >a 24 bit card. If
# >you create a very smooth color gradient of dark-green-white-yellow
# >or something and turn
# >up the contrast on the monitor, you will probably see some mach-banding.
#
#     While I don't mean to damn Henrik's attempt to be helpful here,
# he's using a common misconception that should be corrected.
#
#     Mach banding will occur for any image.  It is not the color
# quantization you see when you don't have enough bits.  It is the
# human eye's response to transitions or edges between intensities.
# The result is that colors near the transistion look brighter on
# the brighter side and darker on the darker side.
#
# --Andre
#
# --
#              Andre Yew andrey@cco.caltech.edu (131.215.139.2)

# %% [markdown]
# Each newsgroup document can have the following sections:
# - header - Contains the standard newsgroup header information. This should be removed.
# - quoted text - Text from a previous message, which usually is prefixed with '>' or '|', and sometimes starts with *writes*, *wrote*, *said*, or *says*.
# - message - Body of the message that you want to extract topics from.
# - footer - Messages typically end with a signature.

# %% [markdown]
# Define the following functions, which you will use to remove the headers, quoted text, and footers.

# %%
import re
def strip_newsgroup_header(text):
    """
    Given text in "news" format, strip the headers, by removing everything
    before the first blank line.
    """
    _before, _blankline, after = text.partition('\n\n')
    return after

_QUOTE_RE = re.compile(r'(writes in|writes:|wrote:|says:|said:'
                       r'|^In article|^Quoted from|^\||^>)')


def strip_newsgroup_quoting(text):
    """
    Given text in "news" format, strip lines beginning with the quote
    characters > or |, plus lines that often introduce a quoted section
    (for example, because they contain the string 'writes:'.)
    """
    good_lines = [line for line in text.split('\n')
                  if not _QUOTE_RE.search(line)]
    return '\n'.join(good_lines)


def strip_newsgroup_footer(text):
    """
    Given text in "news" format, attempt to remove a signature block.

    As a rough heuristic, we assume that signatures are set apart by either
    a blank line or a line made of hyphens, and that it is the last such line
    in the file (disregarding blank lines at the end).
    """
    lines = text.strip().split('\n')
    for line_num in range(len(lines) - 1, -1, -1):
        line = lines[line_num]
        if line.strip().strip('-') == '':
            break

    if line_num > 0:
        return '\n'.join(lines[:line_num])
    else:
        return text
print("cell execution completed")
# Out:
# cell execution completed

# %% [markdown]
# Import the packages you need for preprocessing the dataset.

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from nltk.stem.wordnet import WordNetLemmatizer
print("cell execution completed")
# Out:
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /home/ec2-user/nltk_data...
# cell execution completed
# [nltk_data] Downloading package omw-1.4 to /home/ec2-user/nltk_data...

# %% [markdown]
# Next, remove extra spaces, convert the text to lowercase, and lemmatize the text.

# %%
stop = stopwords.words('english')
lem = WordNetLemmatizer()

def clean(sent):
    # Implement this function
    sent = sent.lower()
    sent = re.sub('\s+', ' ', sent)
    sent = sent.strip()
    sent = re.compile('<.*?>').sub('',sent)
    # Remove special characters and digits
    sent=re.sub("(\\d|\\W)+"," ",sent)
    sent=re.sub("br","",sent)
    filtered_sentence = []
    
    for w in word_tokenize(sent):
        # You are applying custom filtering here. Feel free to try different things.
        # Check if it is not numeric, the length > 2, and it is not in stopwords.
        if(not w.isnumeric()) and (len(w)>2) and (w not in stop):  
            # Stem and add to filtered list
            filtered_sentence.append(lem.lemmatize(w))
    final_string = " ".join(filtered_sentence) # Final string of cleaned words
    return final_string
print("cell execution completed")
# Out:
# cell execution completed

# %% [markdown]
# Read each of the newsgroups messages. Remove the header, quotes, and footers. Then, store the results in an array.

# %%
data = []
source_group = []
for f in file_list:
    with open(f, 'rb') as fin:
        content = fin.read().decode('latin1')   
        content = strip_newsgroup_header(content)
        content = strip_newsgroup_quoting(content)
        content = strip_newsgroup_footer(content)
        content = clean(content)
        # Remove header, quoting, and footer
        data.append(content)
print("cell execution completed")
# Out:
# cell execution completed

# %% [markdown]
# As you can see, the entries in the dataset are now just plain text paragraphs. You need to process them into a data format that the NTM algorithm can understand.

# %%
data[10:13]
# Out:
# ['okay argued thoroughly week ago men woman different physically physiologically psychologically much recent evidence statement present book ainsex anne moir david jessel recommend find copy read book overview recent scientific research topic well referenced woman men different way law adequately take account need area different also taking account way men woman different maternity leave example take account woman get pregnant give woman rule would give men treat woman like treat men instance would unjust simply obvious example men woman intrinsically different people make _naive_ argument sexism oppression however maternity leave sexist men get pregnant men access leave woman extent degree therefore sexist matter however much man _wants_ get pregnant maternity leave never therefore law sexist man access maternity leave matter hard try get pregnant hope clear maternity leave example sexist law sexism reflects sexism nature making men woman different many difference men woman far subtle pregnancy find recommend look book ainsex point perhaps day men also pregnant fallacious men one day become pregnant biologically become woman womb factor required pregnancy usually wrapped definition woman argument examined seen fallacious saying men sexist maternity leave privilege woman also become woman actually support statement maternity leave sexist official priesthood islam much function taken islamic scholar female islamic scholar female islamic scholar always existed islam example early islamic history prophet widow aisha recognized time recognized time islamic scholar evidence blanket statement religion dispute could woman islam etc recently reposted something heading islam woman still news site suggest read reposted soc religion islam disappeared alt atheism still might soc religion islam forgot original title though email like statement religion different think statement based simply lack knowledge religion christianity perhaps judaism aisha mentioned earlier islamic scholar also one stage military leader prophet first wife died hijra prophet journey mecca medina successful businesswoman lucio make strong case viewpoint viewpoint based ignorance world religion',
#  'first buddy second read wrote talking muslim allowed merely practice consider muslim retort old tired must true muslim bullshit gave name information fatwa going leashed perpetrator honestly think someone would voluntarily come forward confess kind extremism shown religionaries fat chance rate conclusive proof nature act perhaps people indulge practice agree theory hope allah forgive end think rather arrogant pretend speak muslim regard also kind silly insinuating koranic law forbids criminal muslim country far care subject weakness argument netters see',
#  'yes look never said implication pretty clear sorry respond word true meaning usenet slippery medium deleted wrt burden proof look supporting dogmatic position fool say large group people atheist people exist wish proselytize fashion religion many hard atheist see posting anyway maybe looking hard enough never meant although understand might get idea merely using bible example allegory illustrate point evidence think may lost thread theist arrogant deleted guilty charged meant say theist arrogant way say thought meaning clear enough position claim superior another supporting evidence arrogant thanks apology btw']

# %% [markdown]
# The next step is to vectorize the data so that it is ready for training. You can use `CountVectorizer`, which you have used in previous labs, and limit the vocabulary size to `vocab_size`.
#
# Use a maximum document frequency of 95 percent of documents (`max_df=0.95`) and a minimum document frequency of 2 documents (`min_df=2`).

# %%
# %%time
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
vocab_size = 2000
print('Tokenizing and counting, this may take a few minutes...')

# vectorizer = CountVectorizer(input='content', max_features=vocab_size, max_df=0.95, min_df=2)
vectorizer = CountVectorizer(input='content', max_features=vocab_size)
vectors = vectorizer.fit_transform(data)
vocab_list = vectorizer.get_feature_names_out()

print('vocab size:', len(vocab_list))
# Out:
# Tokenizing and counting, this may take a few minutes...
# vocab size: 2000
# CPU times: user 1.39 s, sys: 31.9 ms, total: 1.42 s
# Wall time: 1.59 s

# %% [markdown]
# Optionally, consider removing short documents. A short document is not likely to express more than one topic. Topic modeling tries to model each document as a mixture of multiple topics; therefore, topic modeling might not be suitable for short documents.
#
# The following cell removes documents that contain fewer than 25 words.

# %%
threshold = 25
vectors = vectors[np.array(vectors.sum(axis=1)>threshold).reshape(-1,)]
print('removed short docs (<{} words)'.format(threshold))        
print(vectors.shape)
# Out:
# removed short docs (<25 words)
# (10868, 2000)

# %% [markdown]
# The output from `CountVectorizer` are sparse matrices with their elements being integers.

# %%
print(type(vectors), vectors.dtype)
print(vectors[0])
# Out:
# <class 'scipy.sparse._csr.csr_matrix'> int64
#   (0, 1986)	1
#   (0, 747)	3
#   (0, 709)	1
#   (0, 1814)	1
#   (0, 393)	1
#   (0, 1104)	1
#   (0, 1017)	1
#   (0, 586)	1
#   (0, 1668)	1
#   (0, 1918)	1
#   (0, 1326)	1
#   (0, 1780)	1
#   (0, 179)	2
#   (0, 1963)	1
#   (0, 1871)	1
#   (0, 937)	1
#   (0, 186)	1
#   (0, 1544)	1
#   (0, 1991)	1
#   (0, 1167)	1
#   (0, 702)	1
#   (0, 204)	1
#   (0, 1902)	1
#   (0, 326)	1
#   (0, 1535)	1
#   (0, 396)	1
#   (0, 1706)	1
#   (0, 145)	1
#   (0, 1558)	1

# %% [markdown]
# All of the parameters (weights and biases) in the NTM model are `np.float32` type. Therefore, you need the input data to also be `np.float32` type. It is better to do this type-casting up front rather than repeatedly casting during mini-batch training.

# %%
import scipy.sparse as sparse
vectors = sparse.csr_matrix(vectors, dtype=np.float32)
print(type(vectors), vectors.dtype)
# Out:
# <class 'scipy.sparse._csr.csr_matrix'> float32

# %% [markdown]
# # 3. Preparing the data for training
# ([Go to top](#Lab-6.2:-Implementing-Topic-Extraction-with-NTM))

# %% [markdown]
# As a common practice in model training, you should have a training set, validation set, and test set. The training set is the set of data that the model is actually being trained on. You care about the model's performance on future, unseen data. Therefore, during training, you periodically calculate scores (or losses) on the validation set to validate the performance of the model on unseen data. By assessing the model's ability to generalize, you can stop training at the optimal point to avoid overtraining.
#
# Note that when you only have a training set and no validation set, the NTM model will rely on scores on the training set to perform early stopping, which could result in overtraining. Therefore, you should always supply a validation set to the model.
#
# In this lab, you will use 80 percent of the dataset as the training set, and the remaining 20 percent for the validation set and test set. You will use the validation set in training and use the test set to demonstrate model inference.

# %%
from sklearn.model_selection import train_test_split
def split_data(df):
    train, test_validate = train_test_split(df,
                                            test_size=0.2,
                                            shuffle=True,
                                            random_state=324
                                            )
    test, validate = train_test_split(test_validate,
                                            test_size=0.5,
                                            shuffle=True,
                                            random_state=324
                                            )
    return train, validate, test
print("cell execution completed")
# Out:
# cell execution completed

# %%
train_vectors, val_vectors, test_vectors = split_data(vectors)
print("cell execution completed")
# Out:
# cell execution completed

# %%
print(train_vectors.shape, val_vectors.shape)
# Out:
# (8694, 2000) (1087, 2000)

# %% [markdown]
# ## Save the vocabulary file
#
# To make use of the auxiliary channel for the vocabulary file, first save the text file with the name **vocab.txt** in the **auxiliary** directory.

# %%
import os
import shutil
aux_data_dir = os.path.join(data_dir, 'auxiliary')
check_create_dir(aux_data_dir)
with open(os.path.join(aux_data_dir, 'vocab.txt'), 'w', encoding='utf-8') as f:
    for item in vocab_list:
        f.write(item+'\n')
print("cell execution completed")
# Out:
# cell execution completed

# %% [markdown]
# EDITOR COMMENTS for the following cell:
# - In the first sentence, are "recordIO" and "protobuf" two different formats, or are they one format? It's written as if they are one format, but the words link to different URLs. From [this page in the SageMaker documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/cdf-training.html#cdf-recordio-format), I believe it should be written "protobuf recordIO format", but I don't understand why there are two URLs.
# - The URL for "RecordIO" gives a 404 error. The following may be a replacement URL: https://mxnet.apache.org/versions/1.8.0/api/python/docs/api/mxnet/recordio/index.html#mxnet-recordio.
# - The cell says "You will convert..." but then it looks like the actual conversion occurs several cells later. Consider relocating this cell to be closer to the code cell to which it applies.

# %% [markdown]
# ## Store the data on Amazon S3
#
# The NTM algorithm accepts data in the [recordIO - protobuf](https://docs.aws.amazon.com/sagemaker/latest/dg/cdf-training.html) format. The SageMaker Python API provides helper functions to convert your data into this format. You will convert the data from NumPy/SciPy and then upload it to an Amazon Simple Storage Service (Amazon S3) destination for the model to access during training.

# %% [markdown]
# EDITOR COMMENT for the following cell: The cell references "boto regexp", but I don't see that text in any of the code cells within this lab. Should "boto regexp" be in one of the code cells? Should "boto regexp" be replaced with something else here? Is that note applicable to this lab?

# %% [markdown]
# ## Set up AWS credentials
#
# You first need to specify data locations and access roles. In particular, you need the following data:
#
# - The S3 `bucket` and `prefix` that you want to use for the training and model data. This should be within the same Region as the notebook instance, training, and hosting.
# - The AWS Identity and Access Management (IAM) `role` is used to give training and hosting access to your data. See the documentation for how to create these. **Note:** If more than one role is required for notebook instances, training, and/or hosting, replace the `boto regexp` with the appropriate full IAM role Amazon Resource Number (ARN) string or strings.
#
# **Note:** These values will have been supplied when the lab starts.

# %%
import os
import sagemaker
from sagemaker import get_execution_role

role = get_execution_role()

sess = sagemaker.Session()
bucket = "c73485a1491095l3864525t1w423469991745-labbucket-1x1hs3i03weik"
print("cell execution completed")
# Out:
# cell execution completed

# %%
prefix = '20newsgroups-ntm'

train_prefix = os.path.join(prefix, 'train')
val_prefix = os.path.join(prefix, 'val')
aux_prefix = os.path.join(prefix, 'auxiliary')
output_prefix = os.path.join(prefix, 'output')

s3_train_data = os.path.join('s3://', bucket, train_prefix)
s3_val_data = os.path.join('s3://', bucket, val_prefix)
s3_aux_data = os.path.join('s3://', bucket, aux_prefix)
output_path = os.path.join('s3://', bucket, output_prefix)
print('Training set location', s3_train_data)
print('Validation set location', s3_val_data)
print('Auxiliary data location', s3_aux_data)
print('Trained model will be saved at', output_path)
# Out:
# Training set location s3://c73485a1491095l3864525t1w423469991745-labbucket-1x1hs3i03weik/20newsgroups-ntm/train
# Validation set location s3://c73485a1491095l3864525t1w423469991745-labbucket-1x1hs3i03weik/20newsgroups-ntm/val
# Auxiliary data location s3://c73485a1491095l3864525t1w423469991745-labbucket-1x1hs3i03weik/20newsgroups-ntm/auxiliary
# Trained model will be saved at s3://c73485a1491095l3864525t1w423469991745-labbucket-1x1hs3i03weik/20newsgroups-ntm/output

# %% [markdown]
# Now, define a helper function to convert the data to the recordIO protobuf format and upload it to Amazon S3. In addition, you will have the option to split the data into several parts as specified by `n_parts`.
#
# The algorithm inherently supports multiple files in the training folder ("channel"), which could be helpful for a large dataset. In addition, when you use distributed training with multiple workers (compute instances), having multiple files enables you to distribute different portions of the training data to different workers.
#
# This helper function uses the `write_spmatrix_to_sparse_tensor` function, provided by the [SageMaker Python SDK](https://github.com/aws/sagemaker-python-sdk), to convert SciPy sparse matrix into the recordIO protobuf format.

# %%
def split_convert_upload(sparray, bucket, prefix, fname_template='data_part{}.pbr', n_parts=2):
    import io
    import boto3
    import sagemaker.amazon.common as smac
    
    chunk_size = sparray.shape[0]// n_parts
    for i in range(n_parts):

        # Calculate start and end indices
        start = i*chunk_size
        end = (i+1)*chunk_size
        if i+1 == n_parts:
            end = sparray.shape[0]
        
        # Convert to record protobuf
        buf = io.BytesIO()
        smac.write_spmatrix_to_sparse_tensor(array=sparray[start:end], file=buf, labels=None)
        buf.seek(0)
        
        # Upload to S3 location specified by bucket and prefix
        fname = os.path.join(prefix, fname_template.format(i))
        boto3.resource('s3').Bucket(bucket).Object(fname).upload_fileobj(buf)
        print('Uploaded data to s3://{}'.format(os.path.join(bucket, fname)))
print("cell execution completed")
# Out:
# cell execution completed

# %%
split_convert_upload(train_vectors, bucket=bucket, prefix=train_prefix, fname_template='train_part{}.pbr', n_parts=8)
split_convert_upload(val_vectors, bucket=bucket, prefix=val_prefix, fname_template='val_part{}.pbr', n_parts=1)
print("cell execution completed")
# Out:
# Uploaded data to s3://c73485a1491095l3864525t1w423469991745-labbucket-1x1hs3i03weik/20newsgroups-ntm/train/train_part0.pbr
# Uploaded data to s3://c73485a1491095l3864525t1w423469991745-labbucket-1x1hs3i03weik/20newsgroups-ntm/train/train_part1.pbr
# Uploaded data to s3://c73485a1491095l3864525t1w423469991745-labbucket-1x1hs3i03weik/20newsgroups-ntm/train/train_part2.pbr
# Uploaded data to s3://c73485a1491095l3864525t1w423469991745-labbucket-1x1hs3i03weik/20newsgroups-ntm/train/train_part3.pbr
# Uploaded data to s3://c73485a1491095l3864525t1w423469991745-labbucket-1x1hs3i03weik/20newsgroups-ntm/train/train_part4.pbr
# Uploaded data to s3://c73485a1491095l3864525t1w423469991745-labbucket-1x1hs3i03weik/20newsgroups-ntm/train/train_part5.pbr
# Uploaded data to s3://c73485a1491095l3864525t1w423469991745-labbucket-1x1hs3i03weik/20newsgroups-ntm/train/train_part6.pbr
# Uploaded data to s3://c73485a1491095l3864525t1w423469991745-labbucket-1x1hs3i03weik/20newsgroups-ntm/train/train_part7.pbr
# Uploaded data to s3://c73485a1491095l3864525t1w423469991745-labbucket-1x1hs3i03weik/20newsgroups-ntm/val/val_part0.pbr
# cell execution completed

# %% [markdown]
# Upload the vocab.txt file.

# %%
boto3.resource('s3').Bucket(bucket).Object(aux_prefix+'/vocab.txt').upload_file(aux_data_dir+'/vocab.txt')
print("cell execution completed")
# Out:
# cell execution completed

# %% [markdown]
# # 4. Training the model
# ([Go to top](#Lab-6.2:-Implementing-Topic-Extraction-with-NTM))
#
# You have created the training and validation datasets and uploaded them to Amazon S3. Next, configure a SageMaker training job to use the NTM algorithm on the data that you prepared.

# %%
from sagemaker.image_uris import retrieve
container = retrieve('ntm',boto3.Session().region_name)
print("cell execution completed")
# Out:
# cell execution completed

# %% [markdown]
# The code in the following cell automatically chooses an algorithm container based on the current Region. In the API call to `sagemaker.estimator.Estimator`, you also specify the type and count of instances for the training job. Because the 20 Newsgroups dataset is relatively small, you can use a CPU-only instance (`ml.c4.xlarge`).
#
# NTM fully takes advantage of GPU hardware and, in general, trains roughly an order of magnitude faster on a GPU than on a CPU. Multi-GPU or multi-instance training further improves training speed roughly linearly if communication overhead is low compared to compute time.

# %%
import sagemaker
sess = sagemaker.Session()
ntm = sagemaker.estimator.Estimator(container,
                                    role, 
                                    instance_count=2, 
                                    instance_type='ml.c4.xlarge',
                                    output_path=output_path,
                                    sagemaker_session=sagemaker.Session())
print("cell execution completed")
# Out:
# cell execution completed

# %% [markdown]
# EDITOR COMMENT for following cell: This appears to be the only subsection within this task. In general, don't use subsections if only one exists. Recommend removing this heading or adding headings to other subsections within this task.

# %% [markdown]
# ## Set the hyperparameters
#
# The following is a partial list of hyperparameters. For the full list of available hyperparameters, see [NTM Hyperparameters](https://docs.aws.amazon.com/sagemaker/latest/dg/ntm_hyperparameters.html) in the Amazon SageMaker Developer Guide.
#
# - **feature_dim** - The "feature dimension", which should be set to the vocabulary size
# - **num_topics** - The number of topics to extract
# - **mini_batch_size** - The batch size for each worker instance. Note that in multi-GPU instances, this number will be further divided by the number of GPUs. For example, if you plan to train on an 8-GPU machine (such as `ml.p2.8xlarge`) and want each GPU to have 1024 training examples per batch, `mini_batch_size` should be set to 8196.
# - **epochs** - The maximum number of epochs to train for; training may stop early
# - **num_patience_epochs** and **tolerance** - Control the early stopping behavior. In general, early stopping occurs when there hasn't been improvement on validation loss within the last `num_patience_epochs` number of epochs. Improvements smaller than `tolerance` are considered non-improvement.
# - **optimizer** and **learning_rate** - The default optimizer is `adadelta`, and `learning_rate` does not need to be set. For other optimizers, the choice of an appropriate learning rate may require experimentation.

# %%
num_topics = 20
ntm.set_hyperparameters(num_topics=num_topics, 
                        feature_dim=vocab_size, 
                        mini_batch_size=256, 
                        num_patience_epochs=10, 
                        optimizer='adam')
print("cell execution completed")
# Out:
# cell execution completed

# %% [markdown]
# Next, specify how the training data and validation data will be distributed to the workers during training. Data channels have two modes:
#
# - `FullyReplicated`: All data files will be copied to all workers.
# - `ShardedByS3Key`: Data files will be sharded to different workers. Each worker will receive a different portion of the full dataset.
#
# The Python SDK uses the `FullyReplicated` mode for all data channels by default. This is desirable for the validation (test) channel but not for training channel. The reason is that when you use multiple workers, you would like to go through the full dataset by having each worker go through a different portion of the dataset to provide different gradients within epochs. When you use the `FullyReplicated` mode on training data, the training time per epoch is slower (nearly 1.5 times in this example), and it defeats the purpose of distributed training. To set the training data channel correctly, you specify `distribution` to be `ShardedByS3Key` for the training data channel.

# %%
from sagemaker.inputs import TrainingInput
# sagemaker.inputs.TrainingInput
s3_train = TrainingInput(s3_train_data, distribution='ShardedByS3Key') 
s3_val = TrainingInput(s3_val_data, distribution='FullyReplicated')
print("cell execution completed")
# Out:
# cell execution completed

# %% [markdown]
# The final step before training is to define the auxiliary file. This will replace integers in the log files with the actual words.

# %%
s3_aux = TrainingInput(s3_aux_data, distribution='FullyReplicated', content_type='text/plain')
print("cell execution completed")
# Out:
# cell execution completed

# %% [markdown]
# Now you are ready to train. The following cell takes a few minutes to run. The command will first provision the required hardware. You will see a series of dots indicating the progress of the hardware provisioning process. Once the resources are allocated, training logs will be displayed. With multiple workers, the log color and the ID following `INFO` identifies logs that are emitted by different workers.

# %%
# ntm.fit({'train': s3_train, 'validation': s3_train, 'auxiliary': s3_aux})
ntm.fit({'train': s3_train, 'validation': s3_val, 'auxiliary': s3_aux})
print("cell execution completed")
# Out:
# INFO:sagemaker:Creating training-job with name: ntm-2023-04-02-23-23-44-771
# 2023-04-02 23:23:45 Starting - Starting the training job...
# 2023-04-02 23:24:01 Starting - Preparing the instances for training......
# 2023-04-02 23:25:13 Downloading - Downloading input data...
# 2023-04-02 23:25:38 Training - Downloading the training image............
# 2023-04-02 23:27:39 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [04/02/2023 23:27:49 INFO 140256160524096] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/default-input.json: {'encoder_layers': 'auto', 'mini_batch_size': '256', 'epochs': '50', 'encoder_layers_activation': 'sigmoid', 'optimizer': 'adadelta', 'tolerance': '0.001', 'num_patience_epochs': '3', 'batch_norm': 'false', 'rescale_gradient': '1.0', 'clip_gradient': 'Inf', 'weight_decay': '0.0', 'learning_rate': '0.01', 'sub_sample': '1.0', '_tuning_objective_metric': '', '_data_format': 'record', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_kvstore': 'auto_gpu'}
# [04/02/2023 23:27:49 INFO 140256160524096] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '2000', 'mini_batch_size': '256', 'num_patience_epochs': '10', 'num_topics': '20', 'optimizer': 'adam'}
# [04/02/2023 23:27:49 INFO 140256160524096] Final configuration: {'encoder_layers': 'auto', 'mini_batch_size': '256', 'epochs': '50', 'encoder_layers_activation': 'sigmoid', 'optimizer': 'adam', 'tolerance': '0.001', 'num_patience_epochs': '10', 'batch_norm': 'false', 'rescale_gradient': '1.0', 'clip_gradient': 'Inf', 'weight_decay': '0.0', 'learning_rate': '0.01', 'sub_sample': '1.0', '_tuning_objective_metric': '', '_data_format': 'record', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_kvstore': 'auto_gpu', 'feature_dim': '2000', 'num_topics': '20'}
# [04/02/2023 23:27:49 INFO 140256160524096] nvidia-smi: took 0.030 seconds to run.
# [04/02/2023 23:27:49 INFO 140256160524096] nvidia-smi identified 0 GPUs.
# [04/02/2023 23:27:49 INFO 140256160524096] Launching parameter server for role server
# [04/02/2023 23:27:49 INFO 140256160524096] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-205-241.ec2.internal', 'TRAINING_JOB_NAME': 'ntm-2023-04-02-23-23-44-771', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:423469991745:training-job/ntm-2023-04-02-23-23-44-771', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-54d410d2d7f10144d3e541d76f15c9b826db8de80f3d79611d5b389460e5e60b-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml'}
# [04/02/2023 23:27:49 INFO 140256160524096] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-205-241.ec2.internal', 'TRAINING_JOB_NAME': 'ntm-2023-04-02-23-23-44-771', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:423469991745:training-job/ntm-2023-04-02-23-23-44-771', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-54d410d2d7f10144d3e541d76f15c9b826db8de80f3d79611d5b389460e5e60b-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.2.235.247', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [04/02/2023 23:27:49 INFO 140256160524096] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-205-241.ec2.internal', 'TRAINING_JOB_NAME': 'ntm-2023-04-02-23-23-44-771', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:423469991745:training-job/ntm-2023-04-02-23-23-44-771', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-54d410d2d7f10144d3e541d76f15c9b826db8de80f3d79611d5b389460e5e60b-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.2.235.247', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# Process 46 is a shell:server.
# Process 6 is a worker.
# [04/02/2023 23:27:49 INFO 140256160524096] Using default worker.
# [04/02/2023 23:27:49 INFO 140256160524096] Checkpoint loading and saving are disabled.
# [2023-04-02 23:27:49.970] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [04/02/2023 23:27:49 INFO 140256160524096] Initializing
# [04/02/2023 23:27:49 INFO 140256160524096] /opt/ml/input/data/auxiliary
# [04/02/2023 23:27:49 INFO 140256160524096] vocab.txt
# [04/02/2023 23:27:49 INFO 140256160524096] Vocab file vocab.txt is expected at /opt/ml/input/data/auxiliary
# [04/02/2023 23:27:49 INFO 140256160524096] Loading pre-trained token embedding vectors from /opt/amazon/lib/python3.7/site-packages/algorithm/s3_binary/glove.6B.50d.txt
# [04/02/2023 23:27:50 INFO 140185599084352] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/default-input.json: {'encoder_layers': 'auto', 'mini_batch_size': '256', 'epochs': '50', 'encoder_layers_activation': 'sigmoid', 'optimizer': 'adadelta', 'tolerance': '0.001', 'num_patience_epochs': '3', 'batch_norm': 'false', 'rescale_gradient': '1.0', 'clip_gradient': 'Inf', 'weight_decay': '0.0', 'learning_rate': '0.01', 'sub_sample': '1.0', '_tuning_objective_metric': '', '_data_format': 'record', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_kvstore': 'auto_gpu'}
# [04/02/2023 23:27:50 INFO 140185599084352] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '2000', 'mini_batch_size': '256', 'num_patience_epochs': '10', 'num_topics': '20', 'optimizer': 'adam'}
# [04/02/2023 23:27:50 INFO 140185599084352] Final configuration: {'encoder_layers': 'auto', 'mini_batch_size': '256', 'epochs': '50', 'encoder_layers_activation': 'sigmoid', 'optimizer': 'adam', 'tolerance': '0.001', 'num_patience_epochs': '10', 'batch_norm': 'false', 'rescale_gradient': '1.0', 'clip_gradient': 'Inf', 'weight_decay': '0.0', 'learning_rate': '0.01', 'sub_sample': '1.0', '_tuning_objective_metric': '', '_data_format': 'record', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_kvstore': 'auto_gpu', 'feature_dim': '2000', 'num_topics': '20'}
# [04/02/2023 23:27:50 INFO 140185599084352] nvidia-smi: took 0.029 seconds to run.
# [04/02/2023 23:27:50 INFO 140185599084352] nvidia-smi identified 0 GPUs.
# [04/02/2023 23:27:50 INFO 140185599084352] Launching parameter server for role scheduler
# [04/02/2023 23:27:50 INFO 140185599084352] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-235-247.ec2.internal', 'TRAINING_JOB_NAME': 'ntm-2023-04-02-23-23-44-771', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:423469991745:training-job/ntm-2023-04-02-23-23-44-771', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-54d410d2d7f10144d3e541d76f15c9b826db8de80f3d79611d5b389460e5e60b-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml'}
# [04/02/2023 23:27:50 INFO 140185599084352] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-235-247.ec2.internal', 'TRAINING_JOB_NAME': 'ntm-2023-04-02-23-23-44-771', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:423469991745:training-job/ntm-2023-04-02-23-23-44-771', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-54d410d2d7f10144d3e541d76f15c9b826db8de80f3d79611d5b389460e5e60b-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.2.235.247', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [04/02/2023 23:27:50 INFO 140185599084352] Launching parameter server for role server
# [04/02/2023 23:27:50 INFO 140185599084352] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-235-247.ec2.internal', 'TRAINING_JOB_NAME': 'ntm-2023-04-02-23-23-44-771', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:423469991745:training-job/ntm-2023-04-02-23-23-44-771', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-54d410d2d7f10144d3e541d76f15c9b826db8de80f3d79611d5b389460e5e60b-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml'}
# [04/02/2023 23:27:50 INFO 140185599084352] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-235-247.ec2.internal', 'TRAINING_JOB_NAME': 'ntm-2023-04-02-23-23-44-771', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:423469991745:training-job/ntm-2023-04-02-23-23-44-771', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-54d410d2d7f10144d3e541d76f15c9b826db8de80f3d79611d5b389460e5e60b-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.2.235.247', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [04/02/2023 23:27:50 INFO 140185599084352] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-235-247.ec2.internal', 'TRAINING_JOB_NAME': 'ntm-2023-04-02-23-23-44-771', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:423469991745:training-job/ntm-2023-04-02-23-23-44-771', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-54d410d2d7f10144d3e541d76f15c9b826db8de80f3d79611d5b389460e5e60b-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.2.235.247', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# Process 47 is a shell:scheduler.
# Process 56 is a shell:server.
# Process 7 is a worker.
# [04/02/2023 23:27:50 INFO 140185599084352] Using default worker.
# [04/02/2023 23:27:50 INFO 140185599084352] Checkpoint loading and saving are disabled.
# [2023-04-02 23:27:50.102] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [04/02/2023 23:27:50 INFO 140185599084352] Initializing
# [04/02/2023 23:27:50 INFO 140185599084352] /opt/ml/input/data/auxiliary
# [04/02/2023 23:27:50 INFO 140185599084352] vocab.txt
# [04/02/2023 23:27:50 INFO 140185599084352] Vocab file vocab.txt is expected at /opt/ml/input/data/auxiliary
# [04/02/2023 23:27:50 INFO 140185599084352] Loading pre-trained token embedding vectors from /opt/amazon/lib/python3.7/site-packages/algorithm/s3_binary/glove.6B.50d.txt
# [04/02/2023 23:27:59 WARNING 140256160524096] 13 out of 2000 in vocabulary do not have embeddings! Default vector used for unknown embedding!
# [04/02/2023 23:27:59 INFO 140256160524096] Vocab embedding shape: (2000, 50)
# [04/02/2023 23:27:59 WARNING 140185599084352] 13 out of 2000 in vocabulary do not have embeddings! Default vector used for unknown embedding!
# [04/02/2023 23:27:59 INFO 140185599084352] Vocab embedding shape: (2000, 50)
# [04/02/2023 23:27:59 INFO 140185599084352] Number of GPUs being used: 0
# [04/02/2023 23:27:59 INFO 140185599084352] Create Store: dist_async
# #metrics {"StartTime": 1680478079.6904767, "EndTime": 1680478079.6905072, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2023-04-02 23:27:59.690] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 9590, "num_examples": 1, "num_bytes": 104972}
# [04/02/2023 23:27:59 INFO 140185599084352]
# [04/02/2023 23:27:59 INFO 140185599084352] # Starting training for epoch 1
# [04/02/2023 23:27:59 INFO 140256160524096] Number of GPUs being used: 0
# [04/02/2023 23:27:59 INFO 140256160524096] Create Store: dist_async
# #metrics {"StartTime": 1680478079.6905384, "EndTime": 1680478079.690567, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-2", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2023-04-02 23:27:59.690] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 9722, "num_examples": 1, "num_bytes": 104976}
# [04/02/2023 23:27:59 INFO 140256160524096]
# [04/02/2023 23:27:59 INFO 140256160524096] # Starting training for epoch 1
# [2023-04-02 23:28:00.145] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 2, "duration": 454, "num_examples": 17, "num_bytes": 1759556}
# [04/02/2023 23:28:00 INFO 140256160524096] # Finished training epoch 1 on 4350 examples from 17 batches, each of size 256.
# [04/02/2023 23:28:00 INFO 140256160524096] Metrics for Training:
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) total: 7.254746998057646
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) kld: 0.013106567928951015
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) recons: 7.241640399484074
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) logppx: 7.254746998057646
# [04/02/2023 23:28:00 INFO 140256160524096] #quality_metric: host=algo-2, epoch=1, train total_loss <loss>=7.254746998057646
# [2023-04-02 23:28:00.150] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 0, "duration": 10179, "num_examples": 1, "num_bytes": 98728}
# [2023-04-02 23:28:00.212] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 2, "duration": 61, "num_examples": 5, "num_bytes": 412908}
# [04/02/2023 23:28:00 INFO 140256160524096] Finished scoring on 1024 examples from 4 batches, each of size 256.
# [04/02/2023 23:28:00 INFO 140256160524096] Metrics for Inference:
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) total: 7.15298867225647
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) kld: 0.0009322492114733905
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) recons: 7.152056574821472
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) logppx: 7.15298867225647
# [04/02/2023 23:28:00 INFO 140256160524096] #validation_score (1): 7.15298867225647
# [04/02/2023 23:28:00 INFO 140256160524096] Timing: train: 0.46s, val: 0.06s, epoch: 0.52s
# [04/02/2023 23:28:00 INFO 140256160524096] #progress_metric: host=algo-2, completed 2.0 % of epochs
# #metrics {"StartTime": 1680478079.6909351, "EndTime": 1680478080.214299, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-2", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 4350.0, "count": 1, "min": 4350, "max": 4350}, "Total Batches Seen": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Max Records Seen Between Resets": {"sum": 4350.0, "count": 1, "min": 4350, "max": 4350}, "Max Batches Seen Between Resets": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 4350.0, "count": 1, "min": 4350, "max": 4350}, "Number of Batches Since Last Reset": {"sum": 17.0, "count": 1, "min": 17, "max": 17}}}
# [04/02/2023 23:28:00 INFO 140256160524096] #throughput_metric: host=algo-2, train throughput=8309.353955035762 records/second
# [04/02/2023 23:28:00 INFO 140256160524096]
# [04/02/2023 23:28:00 INFO 140256160524096] # Starting training for epoch 2
# [2023-04-02 23:28:00.169] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 2, "duration": 478, "num_examples": 17, "num_bytes": 1711696}
# [04/02/2023 23:28:00 INFO 140185599084352] # Finished training epoch 1 on 4344 examples from 17 batches, each of size 256.
# [04/02/2023 23:28:00 INFO 140185599084352] Metrics for Training:
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) total: 7.2442293447606705
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) kld: 0.01284528338788625
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) recons: 7.231384052949793
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) logppx: 7.2442293447606705
# [04/02/2023 23:28:00 INFO 140185599084352] #quality_metric: host=algo-1, epoch=1, train total_loss <loss>=7.2442293447606705
# [2023-04-02 23:28:00.174] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 0, "duration": 10071, "num_examples": 1, "num_bytes": 98728}
# [2023-04-02 23:28:00.234] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 2, "duration": 59, "num_examples": 5, "num_bytes": 412908}
# [04/02/2023 23:28:00 INFO 140185599084352] Finished scoring on 1024 examples from 4 batches, each of size 256.
# [04/02/2023 23:28:00 INFO 140185599084352] Metrics for Inference:
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) total: 7.152612090110779
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) kld: 0.0009708290890557691
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) recons: 7.151641368865967
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) logppx: 7.152612090110779
# [04/02/2023 23:28:00 INFO 140185599084352] #validation_score (1): 7.152612090110779
# [04/02/2023 23:28:00 INFO 140185599084352] Timing: train: 0.48s, val: 0.06s, epoch: 0.55s
# [04/02/2023 23:28:00 INFO 140185599084352] #progress_metric: host=algo-1, completed 2.0 % of epochs
# #metrics {"StartTime": 1680478079.690852, "EndTime": 1680478080.2366138, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 4344.0, "count": 1, "min": 4344, "max": 4344}, "Total Batches Seen": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Max Records Seen Between Resets": {"sum": 4344.0, "count": 1, "min": 4344, "max": 4344}, "Max Batches Seen Between Resets": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 4344.0, "count": 1, "min": 4344, "max": 4344}, "Number of Batches Since Last Reset": {"sum": 17.0, "count": 1, "min": 17, "max": 17}}}
# [04/02/2023 23:28:00 INFO 140185599084352] #throughput_metric: host=algo-1, train throughput=7957.374710388709 records/second
# [04/02/2023 23:28:00 INFO 140185599084352]
# [04/02/2023 23:28:00 INFO 140185599084352] # Starting training for epoch 2
# [2023-04-02 23:28:00.697] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 460, "num_examples": 17, "num_bytes": 1711696}
# [04/02/2023 23:28:00 INFO 140185599084352] # Finished training epoch 2 on 4344 examples from 17 batches, each of size 256.
# [04/02/2023 23:28:00 INFO 140185599084352] Metrics for Training:
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) total: 7.135309892542222
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) kld: 0.0015323505606776213
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) recons: 7.133777618408203
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) logppx: 7.135309892542222
# [04/02/2023 23:28:00 INFO 140185599084352] #quality_metric: host=algo-1, epoch=2, train total_loss <loss>=7.135309892542222
# [2023-04-02 23:28:00.746] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 5, "duration": 47, "num_examples": 5, "num_bytes": 412908}
# [04/02/2023 23:28:00 INFO 140185599084352] Finished scoring on 1024 examples from 4 batches, each of size 256.
# [04/02/2023 23:28:00 INFO 140185599084352] Metrics for Inference:
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) total: 7.141390919685364
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) kld: 0.0015608194808010012
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) recons: 7.139830112457275
# [04/02/2023 23:28:00 INFO 140185599084352] Loss (name: value) logppx: 7.141390919685364
# [04/02/2023 23:28:00 INFO 140185599084352] #validation_score (2): 7.141390919685364
# [04/02/2023 23:28:00 INFO 140185599084352] Timing: train: 0.46s, val: 0.05s, epoch: 0.52s
# [04/02/2023 23:28:00 INFO 140185599084352] #progress_metric: host=algo-1, completed 4.0 % of epochs
# #metrics {"StartTime": 1680478080.236929, "EndTime": 1680478080.7524893, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 8688.0, "count": 1, "min": 8688, "max": 8688}, "Total Batches Seen": {"sum": 34.0, "count": 1, "min": 34, "max": 34}, "Max Records Seen Between Resets": {"sum": 4344.0, "count": 1, "min": 4344, "max": 4344}, "Max Batches Seen Between Resets": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 4344.0, "count": 1, "min": 4344, "max": 4344}, "Number of Batches Since Last Reset": {"sum": 17.0, "count": 1, "min": 17, "max": 17}}}
# [04/02/2023 23:28:00 INFO 140185599084352] #throughput_metric: host=algo-1, train throughput=8423.231670513049 records/second
# [04/02/2023 23:28:00 INFO 140185599084352]
# [04/02/2023 23:28:00 INFO 140185599084352] # Starting training for epoch 3
# [2023-04-02 23:28:00.735] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 520, "num_examples": 17, "num_bytes": 1759556}
# [04/02/2023 23:28:00 INFO 140256160524096] # Finished training epoch 2 on 4350 examples from 17 batches, each of size 256.
# [04/02/2023 23:28:00 INFO 140256160524096] Metrics for Training:
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) total: 7.133885692147648
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) kld: 0.0014981177621794974
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) recons: 7.132387553944307
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) logppx: 7.133885692147648
# [04/02/2023 23:28:00 INFO 140256160524096] #quality_metric: host=algo-2, epoch=2, train total_loss <loss>=7.133885692147648
# [2023-04-02 23:28:00.798] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 5, "duration": 60, "num_examples": 5, "num_bytes": 412908}
# [04/02/2023 23:28:00 INFO 140256160524096] Finished scoring on 1024 examples from 4 batches, each of size 256.
# [04/02/2023 23:28:00 INFO 140256160524096] Metrics for Inference:
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) total: 7.141079664230347
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) kld: 0.0015687117411289364
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) recons: 7.1395111083984375
# [04/02/2023 23:28:00 INFO 140256160524096] Loss (name: value) logppx: 7.141079664230347
# [04/02/2023 23:28:00 INFO 140256160524096] #validation_score (2): 7.141079664230347
# [04/02/2023 23:28:00 INFO 140256160524096] Timing: train: 0.52s, val: 0.07s, epoch: 0.59s
# [04/02/2023 23:28:00 INFO 140256160524096] #progress_metric: host=algo-2, completed 4.0 % of epochs
# #metrics {"StartTime": 1680478080.2145982, "EndTime": 1680478080.8052318, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-2", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 8700.0, "count": 1, "min": 8700, "max": 8700}, "Total Batches Seen": {"sum": 34.0, "count": 1, "min": 34, "max": 34}, "Max Records Seen Between Resets": {"sum": 4350.0, "count": 1, "min": 4350, "max": 4350}, "Max Batches Seen Between Resets": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 4350.0, "count": 1, "min": 4350, "max": 4350}, "Number of Batches Since Last Reset": {"sum": 17.0, "count": 1, "min": 17, "max": 17}}}
# [04/02/2023 23:28:00 INFO 140256160524096] #throughput_metric: host=algo-2, train throughput=7362.644628099173 records/second
# [04/02/2023 23:28:00 INFO 140256160524096]
# [04/02/2023 23:28:00 INFO 140256160524096] # Starting training for epoch 3
# [2023-04-02 23:28:01.228] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 475, "num_examples": 17, "num_bytes": 1711696}
# [04/02/2023 23:28:01 INFO 140185599084352] # Finished training epoch 3 on 4344 examples from 17 batches, each of size 256.
# [04/02/2023 23:28:01 INFO 140185599084352] Metrics for Training:
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) total: 7.128286922679228
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) kld: 0.0012975413050940808
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) recons: 7.126989392673268
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) logppx: 7.128286922679228
# [04/02/2023 23:28:01 INFO 140185599084352] #quality_metric: host=algo-1, epoch=3, train total_loss <loss>=7.128286922679228
# [2023-04-02 23:28:01.275] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 8, "duration": 45, "num_examples": 5, "num_bytes": 412908}
# [04/02/2023 23:28:01 INFO 140185599084352] Finished scoring on 1024 examples from 4 batches, each of size 256.
# [04/02/2023 23:28:01 INFO 140185599084352] Metrics for Inference:
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) total: 7.140585780143738
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) kld: 0.001189694186905399
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) recons: 7.1393963098526
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) logppx: 7.140585780143738
# [04/02/2023 23:28:01 INFO 140185599084352] #validation_score (3): 7.140585780143738
# [04/02/2023 23:28:01 INFO 140185599084352] Timing: train: 0.48s, val: 0.05s, epoch: 0.53s
# [04/02/2023 23:28:01 INFO 140185599084352] #progress_metric: host=algo-1, completed 6.0 % of epochs
# #metrics {"StartTime": 1680478080.7527974, "EndTime": 1680478081.281743, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 13032.0, "count": 1, "min": 13032, "max": 13032}, "Total Batches Seen": {"sum": 51.0, "count": 1, "min": 51, "max": 51}, "Max Records Seen Between Resets": {"sum": 4344.0, "count": 1, "min": 4344, "max": 4344}, "Max Batches Seen Between Resets": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 4344.0, "count": 1, "min": 4344, "max": 4344}, "Number of Batches Since Last Reset": {"sum": 17.0, "count": 1, "min": 17, "max": 17}}}
# [04/02/2023 23:28:01 INFO 140185599084352] #throughput_metric: host=algo-1, train throughput=8208.634075817448 records/second
# [04/02/2023 23:28:01 INFO 140185599084352]
# [04/02/2023 23:28:01 INFO 140185599084352] # Starting training for epoch 4
# [2023-04-02 23:28:01.278] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 472, "num_examples": 17, "num_bytes": 1759556}
# [04/02/2023 23:28:01 INFO 140256160524096] # Finished training epoch 3 on 4350 examples from 17 batches, each of size 256.
# [04/02/2023 23:28:01 INFO 140256160524096] Metrics for Training:
# [04/02/2023 23:28:01 INFO 140256160524096] Loss (name: value) total: 7.131145477294922
# [04/02/2023 23:28:01 INFO 140256160524096] Loss (name: value) kld: 0.0012358946670942446
# [04/02/2023 23:28:01 INFO 140256160524096] Loss (name: value) recons: 7.129909627577838
# [04/02/2023 23:28:01 INFO 140256160524096] Loss (name: value) logppx: 7.131145477294922
# [04/02/2023 23:28:01 INFO 140256160524096] #quality_metric: host=algo-2, epoch=3, train total_loss <loss>=7.131145477294922
# [2023-04-02 23:28:01.348] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 8, "duration": 68, "num_examples": 5, "num_bytes": 412908}
# [04/02/2023 23:28:01 INFO 140256160524096] Finished scoring on 1024 examples from 4 batches, each of size 256.
# [04/02/2023 23:28:01 INFO 140256160524096] Metrics for Inference:
# [04/02/2023 23:28:01 INFO 140256160524096] Loss (name: value) total: 7.140131592750549
# [04/02/2023 23:28:01 INFO 140256160524096] Loss (name: value) kld: 0.0011868144501931965
# [04/02/2023 23:28:01 INFO 140256160524096] Loss (name: value) recons: 7.138944745063782
# [04/02/2023 23:28:01 INFO 140256160524096] Loss (name: value) logppx: 7.140131592750549
# [04/02/2023 23:28:01 INFO 140256160524096] #validation_score (3): 7.140131592750549
# [04/02/2023 23:28:01 INFO 140256160524096] Timing: train: 0.47s, val: 0.07s, epoch: 0.55s
# [04/02/2023 23:28:01 INFO 140256160524096] #progress_metric: host=algo-2, completed 6.0 % of epochs
# #metrics {"StartTime": 1680478080.805551, "EndTime": 1680478081.3549306, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-2", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 13050.0, "count": 1, "min": 13050, "max": 13050}, "Total Batches Seen": {"sum": 51.0, "count": 1, "min": 51, "max": 51}, "Max Records Seen Between Resets": {"sum": 4350.0, "count": 1, "min": 4350, "max": 4350}, "Max Batches Seen Between Resets": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 4350.0, "count": 1, "min": 4350, "max": 4350}, "Number of Batches Since Last Reset": {"sum": 17.0, "count": 1, "min": 17, "max": 17}}}
# [04/02/2023 23:28:01 INFO 140256160524096] #throughput_metric: host=algo-2, train throughput=7915.88242031717 records/second
# [04/02/2023 23:28:01 INFO 140256160524096]
# [04/02/2023 23:28:01 INFO 140256160524096] # Starting training for epoch 4
# [2023-04-02 23:28:01.950] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 11, "duration": 595, "num_examples": 17, "num_bytes": 1759556}
# [04/02/2023 23:28:01 INFO 140256160524096] # Finished training epoch 4 on 4350 examples from 17 batches, each of size 256.
# [04/02/2023 23:28:01 INFO 140256160524096] Metrics for Training:
# [04/02/2023 23:28:01 INFO 140256160524096] Loss (name: value) total: 7.121721688438864
# [04/02/2023 23:28:01 INFO 140256160524096] Loss (name: value) kld: 0.003372441648560412
# [04/02/2023 23:28:01 INFO 140256160524096] Loss (name: value) recons: 7.118349187514362
# [04/02/2023 23:28:01 INFO 140256160524096] Loss (name: value) logppx: 7.121721688438864
# [04/02/2023 23:28:01 INFO 140256160524096] #quality_metric: host=algo-2, epoch=4, train total_loss <loss>=7.121721688438864
# [2023-04-02 23:28:02.014] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 11, "duration": 61, "num_examples": 5, "num_bytes": 412908}
# [04/02/2023 23:28:02 INFO 140256160524096] Finished scoring on 1024 examples from 4 batches, each of size 256.
# [04/02/2023 23:28:02 INFO 140256160524096] Metrics for Inference:
# [04/02/2023 23:28:02 INFO 140256160524096] Loss (name: value) total: 7.1278159618377686
# [04/02/2023 23:28:02 INFO 140256160524096] Loss (name: value) kld: 0.0035728656221181154
# [04/02/2023 23:28:02 INFO 140256160524096] Loss (name: value) recons: 7.124243140220642
# [04/02/2023 23:28:02 INFO 140256160524096] Loss (name: value) logppx: 7.1278159618377686
# [04/02/2023 23:28:02 INFO 140256160524096] #validation_score (4): 7.1278159618377686
# [04/02/2023 23:28:02 INFO 140256160524096] Timing: train: 0.60s, val: 0.07s, epoch: 0.66s
# [04/02/2023 23:28:02 INFO 140256160524096] #progress_metric: host=algo-2, completed 8.0 % of epochs
# #metrics {"StartTime": 1680478081.3553712, "EndTime": 1680478082.0206373, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-2", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 17400.0, "count": 1, "min": 17400, "max": 17400}, "Total Batches Seen": {"sum": 68.0, "count": 1, "min": 68, "max": 68}, "Max Records Seen Between Resets": {"sum": 4350.0, "count": 1, "min": 4350, "max": 4350}, "Max Batches Seen Between Resets": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Reset Count": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Number of Records Since Last Reset": {"sum": 4350.0, "count": 1, "min": 4350, "max": 4350}, "Number of Batches Since Last Reset": {"sum": 17.0, "count": 1, "min": 17, "max": 17}}}
# [04/02/2023 23:28:02 INFO 140256160524096] #throughput_metric: host=algo-2, train throughput=6536.912558350504 records/second
# [04/02/2023 23:28:02 INFO 140256160524096]
# [04/02/2023 23:28:02 INFO 140256160524096] # Starting training for epoch 5
# [2023-04-02 23:28:01.867] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 11, "duration": 585, "num_examples": 17, "num_bytes": 1711696}
# [04/02/2023 23:28:01 INFO 140185599084352] # Finished training epoch 4 on 4344 examples from 17 batches, each of size 256.
# [04/02/2023 23:28:01 INFO 140185599084352] Metrics for Training:
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) total: 7.122239589691162
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) kld: 0.0024532101610127617
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) recons: 7.119786346659941
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) logppx: 7.122239589691162
# [04/02/2023 23:28:01 INFO 140185599084352] #quality_metric: host=algo-1, epoch=4, train total_loss <loss>=7.122239589691162
# [2023-04-02 23:28:01.937] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 11, "duration": 67, "num_examples": 5, "num_bytes": 412908}
# [04/02/2023 23:28:01 INFO 140185599084352] Finished scoring on 1024 examples from 4 batches, each of size 256.
# [04/02/2023 23:28:01 INFO 140185599084352] Metrics for Inference:
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) total: 7.129017949104309
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) kld: 0.008705927291885018
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) recons: 7.120312213897705
# [04/02/2023 23:28:01 INFO 140185599084352] Loss (name: value) logppx: 7.129017949104309
# [04/02/2023 23:28:01 INFO 140185599084352] #validation_score (4): 7.129017949104309
# [04/02/2023 23:28:01 INFO 140185599084352] Timing: train: 0.59s, val: 0.07s, epoch: 0.66s
# [04/02/2023 23:28:01 INFO 140185599084352] #progress_metric: host=algo-1, completed 8.0 % of epochs
# #metrics {"StartTime": 1680478081.2821789, "EndTime": 1680478081.942987, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 17376.0, "count": 1, "min": 17376, "max": 17376}, "Total Batches Seen": {"sum": 68.0, "count": 1, "min": 68, "max": 68}, "Max Records Seen Between Resets": {"sum": 4344.0, "count": 1, "min": 4344, "max": 4344}, "Max Batches Seen Between Resets": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Reset Count": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Number of Records Since Last Reset": {"sum": 4344.0, "count": 1, "min": 4344, "max": 4344}, "Number of Batches Since Last Reset": {"sum": 17.0, "count": 1, "min": 17, "max": 17}}}
# [04/02/2023 23:28:01 INFO 140185599084352] #throughput_metric: host=algo-1, train throughput=6572.285018410998 records/second
# [04/02/2023 23:28:01 INFO 140185599084352]
# [04/02/2023 23:28:01 INFO 140185599084352] # Starting training for epoch 5
# [2023-04-02 23:28:02.632] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 14, "duration": 689, "num_examples": 17, "num_bytes": 1711696}
# [04/02/2023 23:28:02 INFO 140185599084352] # Finished training epoch 5 on 4344 examples from 17 batches, each of size 256.
# [04/02/2023 23:28:02 INFO 140185599084352] Metrics for Training:
# [04/02/2023 23:28:02 INFO 140185599084352] Loss (name: value) total: 7.117201608770034
# [04/02/2023 23:28:02 INFO 140185599084352] Loss (name: value) kld: 0.003960813381983077
# [04/02/2023 23:28:02 INFO 140185599084352] Loss (name: value) recons: 7.113240802989287
# [04/02/2023 23:28:02 INFO 140185599084352] Loss (name: value) logppx: 7.117201608770034
# [04/02/2023 23:28:02 INFO 140185599084352] #quality_metric: host=algo-1, epoch=5, train total_loss <loss>=7.117201608770034
# [2023-04-02 23:28:02.700] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 14, "duration": 66, "num_examples": 5, "num_bytes": 412908}
# [04/02/2023 23:28:02 INFO 140185599084352] Finished scoring on 1024 examples from 4 batches, each of size 256.
# [04/02/2023 23:28:02 INFO 140185599084352] Metrics for Inference:
# [04/02/2023 23:28:02 INFO 140185599084352] Loss (name: value) total: 7.115433096885681
# [04/02/2023 23:28:02 INFO 140185599084352] Loss (name: value) kld: 0.005878020194359124
# [04/02/2023 23:28:02 INFO 140185599084352] Loss (name: value) recons: 7.109554767608643
# [04/02/2023 23:28:02 INFO 140185599084352] Loss (name: value) logppx: 7.115433096885681
# [04/02/2023 23:28:02 INFO 140185599084352] #validation_score (5): 7.115433096885681
# [04/02/2023 23:28:02 INFO 140185599084352] Timing: train: 0.69s, val: 0.07s, epoch: 0.76s
# [04/02/2023 23:28:02 INFO 140185599084352] #progress_metric: host=algo-1, completed 10.0 % of epochs
# #metrics {"StartTime": 1680478081.9433072, "EndTime": 1680478082.7069864, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 21720.0, "count": 1, "min": 21720, "max": 21720}, "Total Batches Seen": {"sum": 85.0, "count": 1, "min": 85, "max": 85}, "Max Records Seen Between Resets": {"sum": 4344.0, "count": 1, "min": 4344, "max": 4344}, "Max Batches Seen Between Resets": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Reset Count": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Number of Records Since Last Reset": {"sum": 4344.0, "count": 1, "min": 4344, "max": 4344}, "Number of Batches Since Last Reset": {"sum": 17.0, "count": 1, "min": 17, "max": 17}}}
# [04/02/2023 23:28:02 INFO 140185599084352] #throughput_metric: host=algo-1, train throughput=5687.15458555848 records/second
# [04/02/2023 23:28:02 INFO 140185599084352]
# [04/02/2023 23:28:02 INFO 140185599084352] # Starting training for epoch 6
# [2023-04-02 23:28:02.650] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 14, "duration": 629, "num_examples": 17, "num_bytes": 1759556}
# [04/02/2023 23:28:02 INFO 140256160524096] # Finished training epoch 5 on 4350 examples from 17 batches, each of size 256.
# [04/02/2023 23:28:02 INFO 140256160524096] Metrics for Training:
# [04/02/2023 23:28:02 INFO 140256160524096] Loss (name: value) total: 7.11945000816794
# [04/02/2023 23:28:02 INFO 140256160524096] Loss (name: value) kld: 0.003795757088536287
# [04/02/2023 23:28:02 INFO 140256160524096] Loss (name: value) recons: 7.115654328290154
# [04/02/2023 23:28:02 INFO 140256160524096] Loss (name: value) logppx: 7.11945000816794
# [04/02/2023 23:28:02 INFO 140256160524096] #quality_metric: host=algo-2, epoch=5, train total_loss <loss>=7.11945000816794
# [2023-04-02 23:28:02.758] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 14, "duration": 105, "num_examples": 5, "num_bytes": 412908}
# [04/02/2023 23:28:02 INFO 140256160524096] Finished scoring on 1024 examples from 4 batches, each of size 256.
# [04/02/2023 23:28:02 INFO 140256160524096] Metrics for Inference:
# [04/02/2023 23:28:02 INFO 140256160524096] Loss (name: value) total: 7.114989638328552
# [04/02/2023 23:28:02 INFO 140256160524096] Loss (name: value) kld: 0.004357673693448305
# [04/02/2023 23:28:02 INFO 140256160524096] Loss (name: value) recons: 7.110631942749023
# [04/02/2023 23:28:02 INFO 140256160524096] Loss (name: value) logppx: 7.114989638328552
# [04/02/2023 23:28:02 INFO 140256160524096] #validation_score (5): 7.114989638328552
# [04/02/2023 23:28:02 INFO 140256160524096] Timing: train: 0.63s, val: 0.11s, epoch: 0.74s
# [04/02/2023 23:28:02 INFO 140256160524096] #progress_metric: host=algo-2, completed 10.0 % of epochs
# ...
# [04/02/2023 23:28:28 INFO 140256160524096] Finished scoring on 1024 examples from 4 batches, each of size 256.
# [04/02/2023 23:28:28 INFO 140256160524096] Metrics for Inference:
# [04/02/2023 23:28:28 INFO 140256160524096] Loss (name: value) total: 6.821673631668091
# [04/02/2023 23:28:28 INFO 140256160524096] Loss (name: value) kld: 0.09551787376403809
# [04/02/2023 23:28:28 INFO 140256160524096] Loss (name: value) recons: 6.726155757904053
# [04/02/2023 23:28:28 INFO 140256160524096] Loss (name: value) logppx: 6.821673631668091
# [04/02/2023 23:28:28 INFO 140256160524096] #quality_metric: host=algo-2, epoch=50, validation total_loss <loss>=6.821673631668091
# [04/02/2023 23:28:28 INFO 140256160524096] Loss of server-side model: 6.821673631668091
# [04/02/2023 23:28:28 INFO 140256160524096] Best model based on early stopping at epoch 50. Best loss: 6.821673631668091
# [04/02/2023 23:28:28 INFO 140256160524096] Topics from epoch:final (num_topics:20) [wetc 0.29, tu 0.64]:
# [04/02/2023 23:28:28 INFO 140256160524096] [0.21, 0.90] do lib port unix sys vga window usr font modem directory xterm bios zip meg tcp ftp file printer controller
# [04/02/2023 23:28:28 INFO 140256160524096] [0.20, 0.53] ide scsi eye isa drug doctor jumper bullet slave boot blood discussed reaction diet bus morality medicine recognize meg food
# [04/02/2023 23:28:28 INFO 140256160524096] [0.33, 0.73] theory ball fly bible observation caused lord friend hit god knowing consistent crash manager mirror evolution moral born assume bottom
# [04/02/2023 23:28:28 INFO 140256160524096] [0.32, 1.00] playoff game espn season nhl hockey detroit pittsburgh team player montreal toronto ranger league pt nyi stl que tor pitcher
# [04/02/2023 23:28:28 INFO 140256160524096] [0.36, 0.72] cancer hell advice raise doctor active wave belief jesus feeling hole moral explanation burst riding tend spirit discussed stone finding
# [04/02/2023 23:28:28 INFO 140256160524096] [0.29, 0.36] pain eternal medicine atheist marriage passage exists moral objective evolution god msg doctor sin spirit cache universe explanation holy scsi
# [04/02/2023 23:28:28 INFO 140256160524096] [0.40, 0.54] disease pain cancer msg treatment patient food insurance doctor bank spend hit infection accident risk medical abortion vitamin paying aside
# [04/02/2023 23:28:28 INFO 140256160524096] [0.23, 0.56] morality eternal prayer theory judgement greatly diet natural gospel absolute atheist bus colour msg eat verse strike faster jesus mary
# [04/02/2023 23:28:28 INFO 140256160524096] [0.39, 0.58] peter spirit evolution observation morality pain son roman christ god heaven revelation rock eternal catholic mary convert christianity argument scripture
# [04/02/2023 23:28:28 INFO 140256160524096] [0.31, 0.55] decent dog physical universe bat morality pain fan food theory noticed diet study sky msg doctor eternal infection running occurs
# [04/02/2023 23:28:28 INFO 140256160524096] [0.22, 0.38] isa eternal morality msg bus pain god christianity finding infection atheist biblical absolute atheism speed mouse heaven controller choice scsi
# [04/02/2023 23:28:28 INFO 140256160524096] [0.29, 1.00] armenian turkish armenia turk genocide serdar muslim argic ottoman azeri greek max istanbul jew giz bhj turkey arab israel azerbaijan
# [04/02/2023 23:28:28 INFO 140256160524096] [0.31, 0.40] heaven atheism objective evolution jesus judgement bus verse morality atheist son mary gay nearly religion noticed eternal father bible theory
# [04/02/2023 23:28:28 INFO 140256160524096] [0.40, 0.93] bike engine tire rear battery car wheel bmw dealer riding amp ride oil transmission ford motorcycle mile detector fuel drive
# [04/02/2023 23:28:28 INFO 140256160524096] [0.29, 0.53] biblical bible passage objective discussed msg controller slave scientist science mary assumption truth god gay spirit holy dream waste scripture
# [04/02/2023 23:28:28 INFO 140256160524096] [0.24, 0.55] ide scsi controller jumper cache slave bus isa floppy drive bios simms card internal universe pain hard setting ethernet god
# [04/02/2023 23:28:28 INFO 140256160524096] [0.25, 0.43] pain doctor infection objective pitch ball patient vitamin sky interpretation msg hit ford diet configuration universe abortion punishment risk biblical
# [04/02/2023 23:28:28 INFO 140256160524096] [0.33, 0.48] evolution eternal cache bus meg moral heaven absolute pain relationship thinking morality teach sin father accept sex girl god universe
# [04/02/2023 23:28:28 INFO 140256160524096] [0.30, 0.67] abortion disease afford patient infection drug tear male license treatment nsa dollar crypto spread accident damage punishment gas scsi coverage
# [04/02/2023 23:28:28 INFO 140256160524096] [0.21, 0.92] cipher lunar wiretap temperature privacy escrow encryption handgun amendment nsa crypto launch moon warrant assault batf encrypted treatment weapon cryptography
# [04/02/2023 23:28:28 INFO 140256160524096] Serializing model to /opt/ml/model/model_algo-2
# [04/02/2023 23:28:28 INFO 140256160524096] Saved checkpoint to "/tmp/tmpor5ccwwb/state-0001.params"
# [04/02/2023 23:28:28 INFO 140256160524096] Test data is not provided.
# #metrics {"StartTime": 1680478069.9674551, "EndTime": 1680478108.223573, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-2", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 9717.735290527344, "count": 1, "min": 9717.735290527344, "max": 9717.735290527344}, "epochs": {"sum": 50.0, "count": 1, "min": 50, "max": 50}, "model.score.time": {"sum": 2782.1085453033447, "count": 51, "min": 43.5178279876709, "max": 106.82153701782227}, "early_stop.time": {"sum": 2927.0591735839844, "count": 50, "min": 44.02732849121094, "max": 111.06610298156738}, "update.time": {"sum": 28013.033866882324, "count": 50, "min": 492.86723136901855, "max": 892.2288417816162}, "finalize.time": {"sum": 128.8466453552246, "count": 1, "min": 128.8466453552246, "max": 128.8466453552246}, "model.serialize.time": {"sum": 3.77655029296875, "count": 1, "min": 3.77655029296875, "max": 3.77655029296875}, "setuptime": {"sum": 49.47495460510254, "count": 1, "min": 49.47495460510254, "max": 49.47495460510254}, "totaltime": {"sum": 38327.48627662659, "count": 1, "min": 38327.48627662659, "max": 38327.48627662659}}}
# [2023-04-02 23:28:28.041] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 149, "duration": 468, "num_examples": 17, "num_bytes": 1711696}
# [04/02/2023 23:28:28 INFO 140185599084352] # Finished training epoch 50 on 4344 examples from 17 batches, each of size 256.
# [04/02/2023 23:28:28 INFO 140185599084352] Metrics for Training:
# [04/02/2023 23:28:28 INFO 140185599084352] Loss (name: value) total: 6.791592401616714
# [04/02/2023 23:28:28 INFO 140185599084352] Loss (name: value) kld: 0.0898726950673496
# [04/02/2023 23:28:28 INFO 140185599084352] Loss (name: value) recons: 6.701719704796286
# [04/02/2023 23:28:28 INFO 140185599084352] Loss (name: value) logppx: 6.791592401616714
# [04/02/2023 23:28:28 INFO 140185599084352] #quality_metric: host=algo-1, epoch=50, train total_loss <loss>=6.791592401616714
# [2023-04-02 23:28:28.083] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 149, "duration": 40, "num_examples": 5, "num_bytes": 412908}
# [04/02/2023 23:28:28 INFO 140185599084352] Finished scoring on 1024 examples from 4 batches, each of size 256.
# [04/02/2023 23:28:28 INFO 140185599084352] Metrics for Inference:
# [04/02/2023 23:28:28 INFO 140185599084352] Loss (name: value) total: 6.821153163909912
# [04/02/2023 23:28:28 INFO 140185599084352] Loss (name: value) kld: 0.09672082401812077
# [04/02/2023 23:28:28 INFO 140185599084352] Loss (name: value) recons: 6.724432349205017
# [04/02/2023 23:28:28 INFO 140185599084352] Loss (name: value) logppx: 6.821153163909912
# [04/02/2023 23:28:28 INFO 140185599084352] #validation_score (50): 6.821153163909912
# [04/02/2023 23:28:28 INFO 140185599084352] patience losses:[6.85815954208374, 6.850413799285889, 6.845786809921265, 6.845253109931946, 6.850427031517029, 6.834420919418335, 6.8850626945495605, 6.845648288726807, 6.8290287256240845, 6.828770160675049] min patience loss:6.828770160675049 current loss:6.821153163909912 absolute loss difference:0.007616996765136719
# [04/02/2023 23:28:28 INFO 140185599084352] Timing: train: 0.47s, val: 0.05s, epoch: 0.52s
# [04/02/2023 23:28:28 INFO 140185599084352] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1680478107.573456, "EndTime": 1680478108.0890427, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training", "epoch": 49, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 217200.0, "count": 1, "min": 217200, "max": 217200}, "Total Batches Seen": {"sum": 850.0, "count": 1, "min": 850, "max": 850}, "Max Records Seen Between Resets": {"sum": 4344.0, "count": 1, "min": 4344, "max": 4344}, "Max Batches Seen Between Resets": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Reset Count": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "Number of Records Since Last Reset": {"sum": 4344.0, "count": 1, "min": 4344, "max": 4344}, "Number of Batches Since Last Reset": {"sum": 17.0, "count": 1, "min": 17, "max": 17}}}
# [04/02/2023 23:28:28 INFO 140185599084352] #throughput_metric: host=algo-1, train throughput=8422.596979061453 records/second
# [2023-04-02 23:28:28.137] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 152, "duration": 47, "num_examples": 5, "num_bytes": 412908}
# [04/02/2023 23:28:28 INFO 140185599084352] Finished scoring on 1024 examples from 4 batches, each of size 256.
# [04/02/2023 23:28:28 INFO 140185599084352] Metrics for Inference:
# [04/02/2023 23:28:28 INFO 140185599084352] Loss (name: value) total: 6.821673631668091
# [04/02/2023 23:28:28 INFO 140185599084352] Loss (name: value) kld: 0.09551787376403809
# [04/02/2023 23:28:28 INFO 140185599084352] Loss (name: value) recons: 6.726155757904053
# [04/02/2023 23:28:28 INFO 140185599084352] Loss (name: value) logppx: 6.821673631668091
# [04/02/2023 23:28:28 INFO 140185599084352] #quality_metric: host=algo-1, epoch=50, validation total_loss <loss>=6.821673631668091
# [04/02/2023 23:28:28 INFO 140185599084352] Loss of server-side model: 6.821673631668091
# [04/02/2023 23:28:28 INFO 140185599084352] Best model based on early stopping at epoch 50. Best loss: 6.821153163909912
# [04/02/2023 23:28:28 INFO 140185599084352] Topics from epoch:final (num_topics:20) [wetc 0.29, tu 0.66]:
# [04/02/2023 23:28:28 INFO 140185599084352] [0.21, 0.91] do lib port unix sys vga window usr font directory modem xterm bios zip tcp meg ftp printer controller file
# [04/02/2023 23:28:28 INFO 140185599084352] [0.20, 0.54] ide scsi eye doctor isa jumper slave drug bullet discussed blood diet boot reaction medicine recognize bus morality active meg
# [04/02/2023 23:28:28 INFO 140185599084352] [0.30, 0.77] ball fly theory bible lord caused consistent observation knowing crash friend god manager hit born bottom mirror prophet rock voltage
# [04/02/2023 23:28:28 INFO 140185599084352] [0.32, 1.00] playoff espn game season nhl hockey detroit pittsburgh montreal toronto player team nyi ranger league stl pt tor que pitcher
# [04/02/2023 23:28:28 INFO 140185599084352] [0.31, 0.66] cancer hell raise advice doctor active wave feeling belief explanation hole jesus burst moral riding discussed spirit tend stone msg
# [04/02/2023 23:28:28 INFO 140185599084352] [0.33, 0.41] pain eternal medicine marriage atheist passage exists moral evolution msg objective doctor spirit explanation god universe cache sin holy lack
# [04/02/2023 23:28:28 INFO 140185599084352] [0.40, 0.56] disease pain cancer msg treatment bank patient insurance doctor food spend medical infection risk vitamin abortion accident paying hit aside
# [04/02/2023 23:28:28 INFO 140185599084352] [0.26, 0.61] eternal morality prayer greatly theory diet judgement gospel natural absolute faster atheist colour eat bus truly msg strike necessarily verse
# [04/02/2023 23:28:28 INFO 140185599084352] [0.37, 0.53] peter spirit evolution observation morality roman pain son rock christ revelation heaven god eternal convert catholic mary absolute doctor homosexuality
# [04/02/2023 23:28:28 INFO 140185599084352] [0.32, 0.57] decent physical bat dog universe pain morality food fan noticed diet theory sky infection occurs eternal study doctor overall vitamin
# [04/02/2023 23:28:28 INFO 140185599084352] [0.26, 0.50] isa eternal msg morality pain bus finding infection biblical christianity absolute atheism god atheist heaven mouse choice showing saved context
# [04/02/2023 23:28:28 INFO 140185599084352] [0.28, 1.00] armenian turkish armenia turk serdar genocide argic muslim ottoman azeri greek istanbul giz jew max bhj turkey azerbaijan arab village
# [04/02/2023 23:28:28 INFO 140185599084352] [0.30, 0.46] heaven atheism objective judgement jesus evolution bus verse son morality mary atheist noticed nearly gay eternal strange religion father greatly
# [04/02/2023 23:28:28 INFO 140185599084352] [0.38, 0.93] engine bike rear tire battery car wheel riding bmw dealer amp ride transmission motorcycle ford oil mile fuel detector voltage
# [04/02/2023 23:28:28 INFO 140185599084352] [0.29, 0.58] biblical passage bible discussed objective slave scientist msg controller assumption mary spirit science truth waste holy dream gay portion god
# [04/02/2023 23:28:28 INFO 140185599084352] [0.25, 0.63] ide controller scsi jumper cache slave isa bus floppy bios internal drive simms card universe ethernet hard setting pain motherboard
# [04/02/2023 23:28:28 INFO 140185599084352] [0.24, 0.45] pain doctor infection pitch objective ball vitamin patient sky interpretation ford configuration hit diet msg punishment abortion universe biblical larger
# [04/02/2023 23:28:28 INFO 140185599084352] [0.32, 0.50] evolution eternal cache moral bus meg heaven absolute relationship thinking teach pain girl morality sin accept sex universe father feeling
# [04/02/2023 23:28:28 INFO 140185599084352] [0.30, 0.68] abortion disease afford patient infection drug tear male treatment nsa license dollar spread crypto punishment damage gas accident scsi coverage
# [04/02/2023 23:28:28 INFO 140185599084352] [0.20, 0.92] cipher lunar wiretap escrow handgun privacy temperature encryption amendment crypto assault encrypted nsa moon launch warrant batf cryptography secure treatment
# [04/02/2023 23:28:28 INFO 140185599084352] Serializing model to /opt/ml/model/model_algo-1
# [04/02/2023 23:28:28 INFO 140185599084352] Saved checkpoint to "/tmp/tmpdetwyr67/state-0001.params"
# [04/02/2023 23:28:28 INFO 140185599084352] Test data is not provided.
# #metrics {"StartTime": 1680478070.0999289, "EndTime": 1680478108.223246, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 9583.893775939941, "count": 1, "min": 9583.893775939941, "max": 9583.893775939941}, "epochs": {"sum": 50.0, "count": 1, "min": 50, "max": 50}, "model.score.time": {"sum": 2810.4403018951416, "count": 51, "min": 40.862083435058594, "max": 89.07079696655273}, "early_stop.time": {"sum": 2927.539348602295, "count": 50, "min": 45.342445373535156, "max": 89.34235572814941}, "update.time": {"sum": 28370.9397315979, "count": 50, "min": 509.69767570495605, "max": 974.189043045044}, "finalize.time": {"sum": 128.25703620910645, "count": 1, "min": 128.25703620910645, "max": 128.25703620910645}, "model.serialize.time": {"sum": 4.042863845825195, "count": 1, "min": 4.042863845825195, "max": 4.042863845825195}, "setuptime": {"sum": 53.12824249267578, "count": 1, "min": 53.12824249267578, "max": 53.12824249267578}, "totaltime": {"sum": 38202.54874229431, "count": 1, "min": 38202.54874229431, "max": 38202.54874229431}}}
#
# 2023-04-02 23:28:45 Uploading - Uploading generated training model
# 2023-04-02 23:28:45 Completed - Training job completed
# Training seconds: 426
# Billable seconds: 426
# cell execution completed

# %% [markdown]
# If you see the message
#
# > `===== Job Complete =====`
#
# at the bottom of the output logs, then training has successfully completed, and the output NTM model was stored in the specified output path.
#
# You can also view information about a training job on the SageMaker console. In the left navigation pane, under **Training**, choose **Training jobs**. Then, select the training job that matches the training job name from the following cell's output.

# %%
print('Training job name: {}'.format(ntm.latest_training_job.job_name))
print("cell execution completed")
# Out:
# Training job name: ntm-2023-04-02-23-23-44-771
# cell execution completed

# %% [markdown]
# In the cell above that contains the log information for the training job, scroll until you find a line similar to the one in the following cell.
#
# **Tip:** Look for the phrase `Topics from epoch:final`.

# %% [markdown]
#     [05/04/2021 02:01:05 INFO 140593644394304] Topics from epoch:final (num_topics:20) [wetc 0.33, tu 0.68]

# %% [markdown]
# Two numbers are of interest here: **wetc** and **tu**.
#
# - **wetc** is the *word embedding topic coherence* and indicates the degree of topic coherence. A higher number indicates a higher degree of topic coherence.
# - **tu** is the *topic uniqueness* metric and indicates how unique the terms are within the topic. A higher number indicates that the topic terms are more unique.
#
# In the example cell, the wetc is average at 0.33, and the tu is above average at 0.68.

# %% [markdown]
# After the line that displays the overall wetc and tu metrics, you should see a list of topics that were identified along with the words that comprise that topic. Note that the topics are not named. That task still requires a human. For each topic, you see its wetc and tu scores, as well as the top words within that topic.
#
# Review these words, and try to determine a name for each topic.
#
# **Note:** Your results may be different than those in the following cell.

# %% [markdown]
#     [05/04/2021 02:01:05 INFO 140593644394304] [0.60, 0.80] game win playoff player team espn season play detroit baseball cup league score pitcher nhl goal toronto played hockey montreal
#
# Topic 0 seems to be about sports.
#
#     [05/04/2021 02:01:05 INFO 140593644394304] [0.57, 1.00] christ jesus god scripture doctrine christian sin bible faith christianity atheist church religion islam holy heaven biblical eternal morality belief
#
# Topic 1 seems to be about religion.
#
#     [05/04/2021 02:01:05 INFO 140593644394304] [0.30, 0.97] scsi ide motherboard controller drive mhz connector isa slot bus cpu jumper pin meg adapter floppy simms external cache speed
#
# Topic 2 seems to be about computers.
#
# The following topic has a low uniqueness score. It's not clear what this topic would be. Is it something to do with motorcycles, food, or something else? You could name this '**unknown**'.
#
#     [05/04/2021 02:01:05 INFO 140593644394304] [0.35, 0.39] clutch eat bike doctor stopped msg riding watching pitch wheel ride hit food pain feeling personally fix sometimes rear tend

# %% [markdown]
# # 5. Using the model for inference
# ([Go to top](#Lab-6.2:-Implementing-Topic-Extraction-with-NTM))
#
# Now that you have a trained NTM model, use it to perform inference on data. For this example, that means predicting the topic mixture that represents a given document.
#
# To create an inference endpoint, use the SageMaker Python SDK `deploy()` function from the job that you defined previously. Specify the instance type where inference is computed as well as an initial number of instances to launch.

# %%
ntm_predictor = ntm.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
print("cell execution completed")
# Out:
# INFO:sagemaker:Creating model with name: ntm-2023-04-02-23-29-29-108
# INFO:sagemaker:Creating endpoint-config with name ntm-2023-04-02-23-29-29-108
# INFO:sagemaker:Creating endpoint with name ntm-2023-04-02-23-29-29-108
# -------!cell execution completed

# %% [markdown]
# Congratulations! You now have a functioning SageMaker NTM inference endpoint.
#
# You can confirm the endpoint configuration and status in the SageMaker console. In the left navigation pane, under **Inference**, choose **Endpoints**. Then, select the endpoint that matches the endpoint name from the following cell's output.

# %%
print('Endpoint name: {}'.format(ntm_predictor.endpoint_name))
# Out:
# Endpoint name: ntm-2023-04-02-23-29-29-108

# %% [markdown]
# ### Data serialization and deserialization
#
# You can pass data in a variety of formats to the inference endpoint. First, you will pass CSV-formatted data. Use the SageMaker Python SDK utilities `csv_serializer` and `json_deserializer` to configure the inference endpoint.

# %%
ntm_predictor.content_types = 'text/csv'
ntm_predictor.serializer = sagemaker.serializers.CSVSerializer()
ntm_predictor.deserializer = sagemaker.deserializers.JSONDeserializer()
print("cell execution completed")
# Out:
# cell execution completed

# %% [markdown]
# Now,  pass five examples from the test set to the inference endpoint.

# %%
test_data = np.array(test_vectors.todense())
results = ntm_predictor.predict(test_data[:5])
print(results)
# Out:
# {'predictions': [{'topic_weights': [0.0140938209, 0.0414861478, 0.0463782996, 0.0186477974, 0.0409229733, 0.0644611269, 0.0316638649, 0.0521200001, 0.0518632159, 0.0407636091, 0.0571140908, 0.2203110158, 0.0530141182, 0.0169443283, 0.0536947884, 0.0543349758, 0.0412308015, 0.0545545854, 0.0288185254, 0.0175818708]}, {'topic_weights': [0.0330519713, 0.0586114675, 0.04271999, 0.0286279656, 0.0536986291, 0.0398681238, 0.0662510172, 0.0440399013, 0.0404150225, 0.0530306846, 0.0419644155, 0.0341759846, 0.0419435948, 0.0457841009, 0.0402718037, 0.0420194864, 0.0517253391, 0.0426185504, 0.0787847191, 0.1203973591]}, {'topic_weights': [0.0179751106, 0.034184169, 0.0391701199, 0.3597283959, 0.0342382975, 0.0380001552, 0.035043817, 0.0368982144, 0.035433203, 0.0375274606, 0.03567468, 0.0380410627, 0.0385703444, 0.0164985154, 0.0369450264, 0.0330242142, 0.0380927026, 0.0362518057, 0.0316906311, 0.027012147]}, {'topic_weights': [0.2482721061, 0.0499213971, 0.0346836634, 0.053987354, 0.0383370332, 0.0440742709, 0.0365786664, 0.0414040834, 0.0365079343, 0.0373754315, 0.0485488772, 0.0225451384, 0.0441891216, 0.0250410885, 0.0397400893, 0.0552248508, 0.0344174728, 0.0398775637, 0.0397946835, 0.0294791553]}, {'topic_weights': [0.306199342, 0.0444038138, 0.0342213735, 0.0210543778, 0.0399757437, 0.0397612266, 0.0387870185, 0.037223734, 0.034212593, 0.0392212085, 0.0415417515, 0.0257927291, 0.0385775305, 0.0277840272, 0.0353847072, 0.041754365, 0.0364733301, 0.0370125286, 0.0413394049, 0.0392792001]}]}

# %% [markdown]
# The output format of the SageMaker NTM inference endpoint is a Python dictionary with the following format.
#
# ```
# {
#   'predictions': [
#     {'topic_weights': [ ... ] },
#     {'topic_weights': [ ... ] },
#     {'topic_weights': [ ... ] },
#     ...
#   ]
# }
# ```
#
# Extract the topic weights that correspond to each of the input documents.

# %%
predictions = np.array([prediction['topic_weights'] for prediction in results['predictions']])
print(predictions)
# Out:
# [[0.01409382 0.04148615 0.0463783  0.0186478  0.04092297 0.06446113
#   0.03166386 0.05212    0.05186322 0.04076361 0.05711409 0.22031102
#   0.05301412 0.01694433 0.05369479 0.05433498 0.0412308  0.05455459
#   0.02881853 0.01758187]
#  [0.03305197 0.05861147 0.04271999 0.02862797 0.05369863 0.03986812
#   0.06625102 0.0440399  0.04041502 0.05303068 0.04196442 0.03417598
#   0.04194359 0.0457841  0.0402718  0.04201949 0.05172534 0.04261855
#   0.07878472 0.12039736]
#  [0.01797511 0.03418417 0.03917012 0.3597284  0.0342383  0.03800016
#   0.03504382 0.03689821 0.0354332  0.03752746 0.03567468 0.03804106
#   0.03857034 0.01649852 0.03694503 0.03302421 0.0380927  0.03625181
#   0.03169063 0.02701215]
#  [0.24827211 0.0499214  0.03468366 0.05398735 0.03833703 0.04407427
#   0.03657867 0.04140408 0.03650793 0.03737543 0.04854888 0.02254514
#   0.04418912 0.02504109 0.03974009 0.05522485 0.03441747 0.03987756
#   0.03979468 0.02947916]
#  [0.30619934 0.04440381 0.03422137 0.02105438 0.03997574 0.03976123
#   0.03878702 0.03722373 0.03421259 0.03922121 0.04154175 0.02579273
#   0.03857753 0.02778403 0.03538471 0.04175437 0.03647333 0.03701253
#   0.0413394  0.0392792 ]]

# %% [markdown]
# Replace the topic names in the following cell with the topic names that you determined.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
colnames = pd.DataFrame({'topics':['topic 0', 'topic 1', 'topic 2', 'topic 3', 'topic 4', 'topic 5', 'topic 6','topic 7','topic 8','topic 9',
       'topic 10', 'topic 11', 'topic 12', 'topic 13', 'topic 14', 'topic 15', 'topic 16','topic 17','topic 18','topic 19']})
print("cell execution completed")
# Out:
# INFO:matplotlib.font_manager:generated new fontManager
# cell execution completed

# %% [markdown]
# Now, use a bar plot to take a look at how the 20 topics are assigned to the 5 test documents.

# %%
fs = 12
df=pd.DataFrame(predictions.T)
df.index = colnames['topics']
df.plot(kind='bar', figsize=(16,4), fontsize=fs)
plt.ylabel('Topic assignment', fontsize=fs+2)
plt.xlabel('Topic ID', fontsize=fs+2)
print("cell execution completed")
# Out:
# cell execution completed

# %% [markdown]
# You could improve the model by adding or removing specific words to influence topics, increasing or decreasing the number of topics, and trying different hyperparameters.

# %% [markdown]
# ## Delete the endpoint
#
# Finally, delete the endpoint before you close the notebook.
#
# To restart the endpoint, you can follow the code in section 5 using the same `endpoint_name`.

# %%
sagemaker.Session().delete_endpoint(ntm_predictor.endpoint_name)

# %% [markdown]
# # 6. Exploring the model
# ([Go to top](#Lab-6.2:-Implementing-Topic-Extraction-with-NTM))

# %% [markdown]
# **Note: This section provides a deeper exploration of the trained models. The demonstrated functionalities may not be fully supported or guaranteed. For example, the parameter names may change without notice.**
#
# The trained model artifact is a compressed package of MXNet models from the two workers. To explore the model, you first need to install MXNet.

# %%
# If you use the conda_mxnet_p36 kernel, MXNet is already installed; otherwise, uncomment the following line to install it.
# !pip install mxnet 
import mxnet as mx
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting mxnet
#   Downloading mxnet-1.9.1-py3-none-manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 39.7 MB/s eta 0:00:0000:0100:01
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from mxnet) (1.22.3)
# Requirement already satisfied: requests<3,>=2.20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from mxnet) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.20.0->mxnet) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.20.0->mxnet) (1.26.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.20.0->mxnet) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.20.0->mxnet) (2022.12.7)
# Installing collected packages: graphviz, mxnet
# Successfully installed graphviz-0.8.4 mxnet-1.9.1

# %% [markdown]
# Download and unpack the artifact.

# %%
model_path = os.path.join(output_prefix, ntm._current_job_name, 'output/model.tar.gz')
model_path
# Out:
# '20newsgroups-ntm/output/ntm-2023-04-02-23-23-44-771/output/model.tar.gz'

# %%
boto3.resource('s3').Bucket(bucket).download_file(model_path, 'downloaded_model.tar.gz')
print("cell execution completed")
# Out:
# cell execution completed

# %%
# !tar -xzvf 'downloaded_model.tar.gz'
# Out:
# model_algo-2
# model_algo-1

# %%
# Use flag -o to overwrite the previously unzipped content
# !unzip -o model_algo-2
print("cell execution completed")
# Out:
# Archive:  model_algo-2
#  extracting: meta.json
#  extracting: symbol.json
#  extracting: params
# cell execution completed

# %% [markdown]
# Load the model parameters, and extract the weight matrix $W$ in the decoder.

# %%
model = mx.ndarray.load('params')

W = model['arg:projection_weight']
print("cell execution completed")
# Out:
# cell execution completed

# %%
print(W)
# Out:
# [[-0.59657997 -0.05986791 -0.32707265 ... -0.29363823  0.07535974
#    0.24609952]
#  [-0.24308977 -0.05416909  0.07566867 ...  0.10508066  0.17932051
#    0.05532155]
#  [ 0.27779198  0.0359139  -0.00882423 ...  0.05923641  0.04819006
#    0.02246324]
#  ...
#  [-0.0342449  -0.04720178  0.0036606  ... -0.09113839 -0.04228891
#    0.08428033]
#  [ 1.684402   -0.1687115   0.0947125  ... -0.04638032 -0.20958894
#   -0.19941081]
#  [-0.81672573 -0.07381532 -0.11958239 ...  0.04351376 -0.01502261
#    0.05558879]]
# <NDArray 2000x20 @cpu(0)>

# %% [markdown]
# Visualize each topic as a word cloud. The size of each word is proportional to the pseudo-probability of the word appearing under each topic.

# %%
# !pip install wordcloud
import wordcloud as wc
print("cell execution completed")
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (458 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.9/458.9 kB 6.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: numpy>=1.6.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from wordcloud) (1.22.3)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from wordcloud) (3.6.2)
# Requirement already satisfied: pillow in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# cell execution completed

# %%
import matplotlib.pyplot as plt
word_to_id = dict()
for i, v in enumerate(vocab_list):
    word_to_id[v] = i

limit = 24
n_col = 4
counter = 0

plt.figure(figsize=(20,16))
for ind in range(num_topics):

    if counter >= limit:
        break

    title_str = 'Topic{}'.format(ind)

    #pvals = mx.nd.softmax(W[:, ind]).asnumpy()
    pvals = mx.nd.softmax(mx.nd.array(W[:, ind])).asnumpy()

    word_freq = dict()
    for k in word_to_id.keys():
        i = word_to_id[k]
        word_freq[k] =pvals[i]

    wordcloud = wc.WordCloud(background_color='white').fit_words(word_freq)

    plt.subplot(limit // n_col, n_col, counter+1)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title(title_str)
    #plt.close()

    counter +=1
print("cell execution completed")
# Out:
# cell execution completed

# %% [markdown]
# # Congratulations!
#
# You have completed this lab, and you can now end the lab by following the lab guide instructions.

# %% [markdown]
# *©2023 Amazon Web Services, Inc. or its affiliates. All rights reserved. This work may not be reproduced or redistributed, in whole or in part, without prior written permission from Amazon Web Services, Inc. Commercial copying, lending, or selling is prohibited. All trademarks are the property of their owners.*
